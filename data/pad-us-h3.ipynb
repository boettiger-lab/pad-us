# %%
from cng.utils import *

duckdb_install_h3()

import ibis
from ibis import _
con = ibis.duckdb.connect(extensions = ["spatial", "h3"])

import streamlit as st
set_secrets(con, st.secrets["MINIO_KEY"], st.secrets["MINIO_SECRET"])

parquet = "https://minio.carlboettiger.info/public-biodiversity/pad-us-4/pad-us-4.parquet"
con.raw_sql(f"CREATE  OR REPLACE VIEW pad4 AS SELECT Unit_Nm, geom FROM '{parquet}'")

#parquet = "https://minio.carlboettiger.info/public-data/social-vulnerability/2022/SVI2022_US_tract.parquet" # faster with local
#con.raw_sql(f"CREATE  OR REPLACE VIEW svi AS SELECT FIPS, Shape AS geom FROM '{parquet}'")

# %%
# many multi-polygons
con.sql(f'select Unit_Nm, ST_NumGeometries(geom) AS n from pad4 LIMIT 5').execute()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#                                              Unit_Nm   n
# 0          Laguna Cartagena National Wildlife Refuge   1
# 1      Servidumbre de Conservación Finca María Luisa   2
# 2                Servidumbre Escénica Montes Oscuros  10
# 3     Servidumbre de Conservación Siembra Tres Vidas   1
# 4  Servidumbre de Conservación Centro Espríritu S...   1

# %%
# test case
con.sql(f'''
WITH t1 AS (
SELECT Unit_Nm, 
       ST_Dump(geom) AS geom 
FROM pad4 LIMIT 5)
SELECT Unit_Nm, UNNEST(geom).geom FROM t1
''').execute()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#                                               Unit_Nm  \
# 0           Laguna Cartagena National Wildlife Refuge
# 1       Servidumbre de Conservación Finca María Luisa
# 2       Servidumbre de Conservación Finca María Luisa
# 3                 Servidumbre Escénica Montes Oscuros
# 4                 Servidumbre Escénica Montes Oscuros
# 5                 Servidumbre Escénica Montes Oscuros
# 6                 Servidumbre Escénica Montes Oscuros
# 7                 Servidumbre Escénica Montes Oscuros
# 8                 Servidumbre Escénica Montes Oscuros
# 9                 Servidumbre Escénica Montes Oscuros
# 10                Servidumbre Escénica Montes Oscuros
# 11                Servidumbre Escénica Montes Oscuros
# 12                Servidumbre Escénica Montes Oscuros
# 13     Servidumbre de Conservación Siembra Tres Vidas
# 14  Servidumbre de Conservación Centro Espríritu S...
#
#                                   (unnest(geom)).geom
# 0   POLYGON ((-67.10254 18.00731, -67.10250 18.006...
# 1   POLYGON ((-67.10363 17.99423, -67.10309 17.994...
# 2   POLYGON ((-67.08988 17.98585, -67.08985 17.985...
# 3   POLYGON ((-66.27890 18.06995, -66.27151 18.069...
# 4   POLYGON ((-66.24115 18.04572, -66.24158 18.044...
# 5   POLYGON ((-66.30271 18.01735, -66.30289 18.017...
# 6   POLYGON ((-66.30415 18.01854, -66.30427 18.018...
# 7   POLYGON ((-66.28831 18.01846, -66.28827 18.018...
# 8   POLYGON ((-66.29271 18.01361, -66.29286 18.013...
# 9   POLYGON ((-66.29476 18.01378, -66.29474 18.013...
# 10  POLYGON ((-66.29513 18.01343, -66.29527 18.013...
# 11  POLYGON ((-66.31348 18.01109, -66.31357 18.011...
# 12  POLYGON ((-66.29560 17.99291, -66.29554 17.992...
# 13  POLYGON ((-66.25836 18.09915, -66.25844 18.099...
# 14  POLYGON ((-66.26600 18.16632, -66.26599 18.166...

# %%
zoom = 11

con.sql(f'''
WITH t1 AS (
  SELECT Unit_Nm, ST_Dump(geom) AS geom 
  FROM pad4
) 
SELECT Unit_Nm, 
       h3_polygon_wkt_to_cells_string(UNNEST(geom).geom, {zoom}) AS cells
FROM t1
''').to_parquet(f"s3://public-biodiversity/pad-us-4/pad-h3-z{zoom}.parquet")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#                                               Unit_Nm  \
# 0           Laguna Cartagena National Wildlife Refuge
# 1       Servidumbre de Conservación Finca María Luisa
# 2       Servidumbre de Conservación Finca María Luisa
# 3                 Servidumbre Escénica Montes Oscuros
# 4                 Servidumbre Escénica Montes Oscuros
# 5                 Servidumbre Escénica Montes Oscuros
# 6                 Servidumbre Escénica Montes Oscuros
# 7                 Servidumbre Escénica Montes Oscuros
# 8                 Servidumbre Escénica Montes Oscuros
# 9                 Servidumbre Escénica Montes Oscuros
# 10                Servidumbre Escénica Montes Oscuros
# 11                Servidumbre Escénica Montes Oscuros
# 12                Servidumbre Escénica Montes Oscuros
# 13     Servidumbre de Conservación Siembra Tres Vidas
# 14  Servidumbre de Conservación Centro Espríritu S...
# 15             Servidumbre de Conservación El Rabanal
# 16              Servidumbre de Conservación El Tambor
# 17  Servidumbre de Conservación Bosque Tropical Pa...
# 18  Servidumbre de Conservación Bosque Tropical Pa...
# 19  Servidumbre de Conservación Bosque Tropical Pa...
# 20  Servidumbre de Conservación Bosque Tropical Pa...
# 21  Servidumbre de Conservación Bosque Tropical Pa...
# 22  Servidumbre de Conservación Bosque Tropical Pa...
# 23  Servidumbre de Conservación Bosque Tropical Pa...
# 24  Servidumbre de Conservación Bosque Tropical Pa...
# 25  Servidumbre de Conservación Bosque Tropical Pa...
# 26  Servidumbre de Conservación Bosque Tropical Pa...
# 27  Servidumbre de Conservación Bosque Tropical Pa...
# 28            Servidumbre de Conservación Finca Gulín
# 29                   Culebra National Wildlife Refuge
# 30                   Culebra National Wildlife Refuge
# 31                       Virgin Islands National Park
# 32                       Virgin Islands National Park
# 33  Servidumbre de Conservación Finca Ledesma Moulier
# 34                Servidumbre de Conservación Foreman
# 35               Servidumbre de Conservación Picaflor
# 36  NC Coastal Land Trust - Acq/ Springer's Point/...
#
#                                                 cells
# 0   [8b4cc0b51a11fff, 8b4cc0b4242cfff, 8b4cc0b420e...
# 1   [8b4cc0b5c54bfff, 8b4cc0b5c40bfff, 8b4cc0b5c0d...
# 2   [8b4cc0b58aaafff, 8b4cc0b59c81fff, 8b4cc0b58da...
# 3   [8b4cead904dcfff, 8b4cead9249cfff, 8b4cead9641...
# 4   [8b4cead91534fff, 8b4cead90264fff, 8b4cead91c8...
# 5   [8b4cc536339afff, 8b4cc53632b4fff, 8b4cc536339...
# 6                                                  []
# 7   [8b4cc536ececfff, 8b4cc536e191fff, 8b4cc536ed6...
# 8                                   [8b4cc536e575fff]
# 9                                                  []
# 10                                  [8b4cc536e51bfff]
# 11                 [8b4cc5345c9efff, 8b4cc5345c93fff]
# 12  [8b4cc536a4a9fff, 8b4cc536a4f6fff, 8b4cc536a41...
# 13  [8b4ceadb6496fff, 8b4ceadb649afff, 8b4cc5acd86...
# 14  [8b4cc5a52454fff, 8b4cc5a52455fff, 8b4cc5a5240...
# 15  [8b4cc5a43551fff, 8b4cc5a43421fff, 8b4cc5a4356...
# 16  [8b4cc5baa121fff, 8b4cc5bae398fff, 8b4cc5baac2...
# 17  [8b4cea812ce2fff, 8b4cea812c5dfff, 8b4cea812c4...
# 18  [8b4cea8a1218fff, 8b4cea8a1203fff, 8b4cea8a1ad...
# 19  [8b4cea8acc00fff, 8b4cea8acc76fff, 8b4cea8acc0...
# 20  [8b4cea8ac122fff, 8b4cea8ac131fff, 8b4cea8ac10...
# 21  [8b4cea8ac89afff, 8b4cea8acc62fff, 8b4cea8acc6...
# 22  [8b4cea8a1273fff, 8b4cea8acc98fff, 8b4cea8acc1...
# 23  [8b4cea8ac196fff, 8b4cea8accc3fff, 8b4cea8accc...
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27  [8b4cea8ac555fff, 8b4cea8ac572fff, 8b4cea8ac57...
# 28  [8b4cea924408fff, 8b4cea9244ebfff, 8b4cea92479...
# 29  [8b4ce8542b80fff, 8b4ce8542b84fff, 8b4ce8542b8...
# 30  [8b4ce85736b6fff, 8b4ce8573695fff, 8b4ce85736d...
# 31  [8b4ce8a85af0fff, 8b4ce8a85af2fff, 8b4ce8a85af...
# 32                                                 []
# 33  [8b4cc506a36bfff, 8b4cc506a370fff, 8b4cc506aa1...
# 34  [8b4cc50c0516fff, 8b4cc50c0504fff, 8b4cc50c046...
# 35  [8b4cc53b60c6fff, 8b4cc53b6051fff, 8b4cc53b650...
# 36  [8b2af335bac4fff, 8b2af3266d88fff, 8b2af335bac...
